# %%
# 데이터 확인 작업
import pandas as pd

# %%
busan_food = pd.read_csv('../Data_Store/Processed_data/busan_food.csv', encoding='utf-8')

# %%
busan_food.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
busan_food
# Out:
#         번호   개방서비스명     개방서비스ID  개방자치단체코드                    관리번호     인허가일자  \
# 0        1  식품제조가공업  07_22_11_P   3290000  3290000-106-2002-01621  20020913
# 1        2  식품제조가공업  07_22_11_P   3350000  3350000-106-2006-00015  20061213
# 2        3  식품제조가공업  07_22_11_P   3360000  3360000-106-2006-00006  20060605
# 3        4  식품제조가공업  07_22_11_P   3360000  3360000-106-2001-00080  20010409
# 4        5  식품제조가공업  07_22_11_P   3380000  3380000-106-2017-00005  20170621
# ...    ...      ...         ...       ...                     ...       ...
# 4733  4734  식품제조가공업  07_22_11_P   3300000  3300000-106-1998-00001  19981104
# 4734  4735  식품제조가공업  07_22_11_P   3300000  3300000-106-1998-00134  19981118
# 4735  4736  식품제조가공업  07_22_11_P   3300000  3300000-106-1998-00158  19981202
# 4736  4737  식품제조가공업  07_22_11_P   3300000  3300000-106-1998-00015  19981215
# 4737  4738  식품제조가공업  07_22_11_P   3300000  3300000-106-1999-00664  19990325
#
# ...

# %%
busan_food.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스ID', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)',
#        '위생업태명', '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총종업원수',
#        '본사종업원수', '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액',
#        '월세액', '다중이용업소여부', '시설총규모', '전통업소지정번호', '전통업소주된음식', '홈페이지'],
#       dtype='object')

# %%
missing = busan_food.shape[0] - busan_food.count()
missing
# Out:
# 번호              0
# 개방서비스명          0
# 개방서비스ID         0
# 개방자치단체코드        0
# 관리번호            0
# 인허가일자           0
# 인허가취소일자      4738
# 영업상태구분코드        0
# 영업상태명           0
# 상세영업상태코드        0
# 상세영업상태명         0
# 폐업일자         1374
# 휴업시작일자       4738
# 휴업종료일자       4738
# 재개업일자        4738
# 소재지전화         866
# 소재지면적         643
# 소재지우편번호        92
# 소재지전체주소         5
# 도로명전체주소      2182
# 도로명우편번호      2227
# 사업장명            0
# 최종수정시점          0
# 데이터갱신구분         0
# 데이터갱신일자         0
# 업태구분명         175
# 좌표정보(X)       242
# 좌표정보(Y)       242
# 위생업태명         175
# 남성종사자수       3858
# 여성종사자수       3859
# 영업장주변구분명     3223
# 등급구분명        3223
# 급수시설구분명      2932
# 총종업원수        4738
# 본사종업원수       1672
# 공장사무직종업원수    1651
# 공장판매직종업원수    1668
# 공장생산직종업원수    1617
# 건물소유구분명      2976
# 보증액          4424
# 월세액          4424
# 다중이용업소여부        0
# 시설총규모           0
# 전통업소지정번호     4738
# 전통업소주된음식     4738
# 홈페이지         4661
# dtype: int64

# %%
newcol = ['개방서비스명','인허가일자', '인허가취소일자', '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '소재지면적', '소재지전체주소', '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)','위생업태명', '남성종사자수', '여성종사자수', '다중이용업소여부', '시설총규모']

# %%
busan_food_nor = busan_food[newcol]

# %%
busan_food_nor.head()
# Out:
#     개방서비스명     인허가일자  인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명  폐업일자  \
# 0  식품제조가공업  20020913      NaN         1  영업/정상         1      영업   NaN
# 1  식품제조가공업  20061213      NaN         1  영업/정상         1      영업   NaN
# 2  식품제조가공업  20060605      NaN         1  영업/정상         1      영업   NaN
# 3  식품제조가공업  20010409      NaN         1  영업/정상         1      영업   NaN
# 4  식품제조가공업  20170621      NaN         1  영업/정상         1      영업   NaN
#
#       소재지면적                  소재지전체주소  ... 데이터갱신구분                데이터갱신일자  \
# 0    140.89  부산광역시 부산진구 부전동 347-23번지  ...       U  2019-10-09 02:40:00.0
# 1     45.04    부산광역시 금정구 남산동 952-2번지  ...       I  2018-08-31 23:59:59.0
# 2    925.60   부산광역시 강서구 송정동 1761-6번지  ...       I  2018-08-31 23:59:59.0
# 3  1,549.00     부산광역시 강서구 녹산동 97-5번지  ...       I  2018-08-31 23:59:59.0
# 4    235.68   부산광역시 수영구 망미동 206-11번지  ...       I  2018-08-31 23:59:59.0
#
#         업태구분명        좌표정보(X)        좌표정보(Y)       위생업태명  남성종사자수 여성종사자수  \
# ...

# %%
missing = busan_food_nor.shape[0] - busan_food_nor.count()

# %%
missing
# Out:
# 개방서비스명         0
# 인허가일자          0
# 인허가취소일자     4738
# 영업상태구분코드       0
# 영업상태명          0
# 상세영업상태코드       0
# 상세영업상태명        0
# 폐업일자        1374
# 소재지면적        643
# 소재지전체주소        5
# 사업장명           0
# 최종수정시점         0
# 데이터갱신구분        0
# 데이터갱신일자        0
# 업태구분명        175
# 좌표정보(X)      242
# 좌표정보(Y)      242
# 위생업태명        175
# 남성종사자수      3858
# 여성종사자수      3859
# 다중이용업소여부       0
# 시설총규모          0
# dtype: int64

# %%
busan_food_nor.columns
# Out:
# Index(['개방서비스명', '인허가일자', '인허가취소일자', '영업상태구분코드', '영업상태명', '상세영업상태코드',
#        '상세영업상태명', '폐업일자', '소재지면적', '소재지전체주소', '사업장명', '최종수정시점', '데이터갱신구분',
#        '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명', '남성종사자수', '여성종사자수',
#        '다중이용업소여부', '시설총규모'],
#       dtype='object')

# %%
newcol = ['개방서비스명', '인허가일자','영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '소재지면적', '소재지전체주소', '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명', '다중이용업소여부', '시설총규모']

# %%
newcol
# Out:
# ['개방서비스명',
#  '인허가일자',
#  '영업상태구분코드',
#  '영업상태명',
#  '상세영업상태코드',
#  '상세영업상태명',
#  '폐업일자',
#  '소재지면적',
#  '소재지전체주소',
#  '사업장명',
#  '최종수정시점',
#  '데이터갱신구분',
#  '데이터갱신일자',
#  '업태구분명',
#  '좌표정보(X)',
#  '좌표정보(Y)',
#  '위생업태명',
#  '다중이용업소여부',
#  '시설총규모']

# %%
busan_food_nor = busan_food_nor[newcol]

# %%
busan_food_nor.head()
# Out:
#     개방서비스명     인허가일자  영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명  폐업일자     소재지면적  \
# 0  식품제조가공업  20020913         1  영업/정상         1      영업   NaN    140.89
# 1  식품제조가공업  20061213         1  영업/정상         1      영업   NaN     45.04
# 2  식품제조가공업  20060605         1  영업/정상         1      영업   NaN    925.60
# 3  식품제조가공업  20010409         1  영업/정상         1      영업   NaN  1,549.00
# 4  식품제조가공업  20170621         1  영업/정상         1      영업   NaN    235.68
#
#                    소재지전체주소               사업장명          최종수정시점 데이터갱신구분  \
# 0  부산광역시 부산진구 부전동 347-23번지               동일식품  20191007163850       U
# 1    부산광역시 금정구 남산동 952-2번지              제빵소 작  20170726144834       I
# 2   부산광역시 강서구 송정동 1761-6번지     에스엔푸드(SN FOOD)  20170102110559       I
# 3     부산광역시 강서구 녹산동 97-5번지            진해물산(주)  20170502103713       I
# 4   부산광역시 수영구 망미동 206-11번지  커피덕트(COFFEE DUCT)  20180426164041       I
#
#                  데이터갱신일자       업태구분명        좌표정보(X)        좌표정보(Y)  \
# ...

# %%
busan_food_cafe = busan_food_nor[busan_food_nor['사업장명'].str.findall(pat = '.*커피|카페|로스터리|로스팅.*').str.len() != 0]

# %%
busan_food_cafe.reset_index(drop = True, inplace = True)

# %%
busan_food_cafe.shape
# Out:
# (169, 19)

# %%
busan_food_cafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 19 columns):
# 개방서비스명      169 non-null object
# 인허가일자       169 non-null int64
# 영업상태구분코드    169 non-null int64
# 영업상태명       169 non-null object
# 상세영업상태코드    169 non-null int64
# 상세영업상태명     169 non-null object
# 폐업일자        64 non-null float64
# 소재지면적       165 non-null object
# 소재지전체주소     169 non-null object
# 사업장명        169 non-null object
# 최종수정시점      169 non-null int64
# 데이터갱신구분     169 non-null object
# 데이터갱신일자     169 non-null object
# 업태구분명       169 non-null object
# 좌표정보(X)     169 non-null float64
# 좌표정보(Y)     169 non-null float64
# 위생업태명       169 non-null object
# 다중이용업소여부    169 non-null object
# 시설총규모       169 non-null float64
# dtypes: float64(4), int64(4), object(11)
# memory usage: 25.2+ KB

# %%
missing = busan_food_cafe.shape[0] - busan_food_cafe.count()

# %%
missing
# Out:
# 개방서비스명        0
# 인허가일자         0
# 영업상태구분코드      0
# 영업상태명         0
# 상세영업상태코드      0
# 상세영업상태명       0
# 폐업일자        105
# 소재지면적         4
# 소재지전체주소       0
# 사업장명          0
# 최종수정시점        0
# 데이터갱신구분       0
# 데이터갱신일자       0
# 업태구분명         0
# 좌표정보(X)       0
# 좌표정보(Y)       0
# 위생업태명         0
# 다중이용업소여부      0
# 시설총규모         0
# dtype: int64

# %%
busan_food_cafe.to_csv('../Staging_Tables/busan_food_cafe.csv', encoding = 'euc-kr')
